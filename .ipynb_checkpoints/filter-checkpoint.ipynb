# %%
from glob import glob
import pandas as pd
import matplotlib.pyplot as plt

# %%
sta = pd.read_csv("CWB_Stations_171226.csv")

# %%
stal = list(sta.id)
ignore = []

# %%
list(df_tmp)
# Out:
# ['ObsTime',
#  'StnPres',
#  'SeaPres',
#  'StnPresMax',
#  'StnPresMaxTime',
#  'StnPresMin',
#  'StnPresMinTime',
#  'Temperature',
#  'T Max',
#  'T Max Time',
#  'T Min',
#  'T Min Time',
#  'Td dew point',
#  'WS',
#  'WD',
#  'WSGust',
#  'WDGust',
#  'WGustTime',
#  'Precp',
#  'PrecpHour',
#  'PrecpDay',
#  'PrecpMax10',
#  'PrecpMax10Time',
#  'PrecpHrMax',
#  'PrecpHrMaxTime',
#  'Precp1DayMax',
#  'Precp1DayMaxTime',
#  'RH',
#  'EvapA',
#  'SunShine',
#  'GloblRad',
#  'UVI Max Mean',
#  'UVI Max',
#  'UVI Max Time',
#  'Cloud Amount']

# %%
for j in range(len(sta)):
    if stal[j] not in ignore:
        file = glob("data/Yearly/{}/*.txt".format(stal[j]))
        print("Checking the data on station",stal[j])
        try:
            for i,f in enumerate(file):
                df_tmp = pd.read_csv(file[i],index_col=0)
                if i == 0:
                    df = df_tmp
                else:
                    df = pd.concat([df,df_tmp])
            df['Time'] = df["StnPresMinTime"].str[0:7]
            dff = pd.DataFrame([[float(a) for a in list(df.Precp)]],columns= list(df.Time),index=[stal[j]])
            dff['long'] = len(dff) * [0.0]
            dff['lat'] = len(dff) * [0.0]
            dff['name'] = len(dff) * ''
            dff.loc[stal[j],"long"] = float(sta["long"][sta["id"]==stal[j]])
            dff.loc[stal[j],"lat"] = float(sta["lat"][sta["id"]==stal[j]])
            dff.loc[stal[j],"name"] = stal[j]
            DF_tmp = dff
            if j == 0:
                DF = DF_tmp
            else:
                DF = pd.concat([DF,DF_tmp]) 
        except:
            print(stal[j]," problem")
            ignore.append(stal[j])
            pass        
#    DF = DF.dropna(axis = 0, thresh = 10)
    DF.to_csv("precp.csv")
# Out:
# Checking the data on station 466850
# Checking the data on station 466880
# Checking the data on station 466900
# Checking the data on station 466910
# Checking the data on station 466920
# Checking the data on station 466930
# Checking the data on station 466940
# Checking the data on station 466950
# Checking the data on station 466990
# Checking the data on station 467050
# 467050  problem
# Checking the data on station 467060
# Checking the data on station 467080
# Checking the data on station 467110
# 467110  problem
# Checking the data on station 467300
# 467300  problem
# Checking the data on station 467350
# 467350  problem
# Checking the data on station 467410
# Checking the data on station 467420
# 467420  problem
# Checking the data on station 467440
# 467440  problem
# Checking the data on station 467480
# 467480  problem
# Checking the data on station 467490
# Checking the data on station 467530
# Checking the data on station 467540
# Checking the data on station 467550
# Checking the data on station 467571
# Checking the data on station 467590
# Checking the data on station 467610
# Checking the data on station 467620
# Checking the data on station 467650
# 467650  problem
# Checking the data on station 467660
# Checking the data on station 467770
# 467770  problem
# Checking the data on station 467790
# Checking the data on station 467990
# Checking the data on station C0A520
# Checking the data on station C0A530
# Checking the data on station C0A540
# Checking the data on station C0A550
# Checking the data on station C0A560
# Checking the data on station C0A570
# Checking the data on station C0A580
# Checking the data on station C0A640
# Checking the data on station C0A650
# Checking the data on station C0A660
# Checking the data on station C0A860
# Checking the data on station C0A870
# Checking the data on station C0A880
# Checking the data on station C0A890
# Checking the data on station C0A920
# Checking the data on station C0A931
# C0A931  problem
# Checking the data on station C0A940
# Checking the data on station C0A950
# Checking the data on station C0A970
# C0A970  problem
# Checking the data on station C0A980
# Checking the data on station C0A9A0
# Checking the data on station C0A9B0
# Checking the data on station C0A9C0
# Checking the data on station C0A9E0
# Checking the data on station C0A9F0
# Checking the data on station C0A9G0
# Checking the data on station C0A9I1
# Checking the data on station C0AC40
# Checking the data on station C0AC60
# Checking the data on station C0AC70
# Checking the data on station C0AC80
# Checking the data on station C0ACA0
# Checking the data on station C0AD00
# Checking the data on station C0AD10
# Checking the data on station C0AD30
# Checking the data on station C0AD40
# Checking the data on station C0AD50
# Checking the data on station C0AG90
# C0AG90  problem
# Checking the data on station C0AH00
# C0AH00  problem
# Checking the data on station C0AH10
# C0AH10  problem
# Checking the data on station C0AH30
# C0AH30  problem
# Checking the data on station C0AH40
# C0AH40  problem
# Checking the data on station C0AH50
# C0AH50  problem
# Checking the data on station C0AH70
# C0AH70  problem
# Checking the data on station C0AH80
# C0AH80  problem
# Checking the data on station C0C460
# Checking the data on station C0C480
# Checking the data on station C0C490
# C0C490  problem
# Checking the data on station C0C520
# Checking the data on station C0C540
# Checking the data on station C0C590
# C0C590  problem
# Checking the data on station C0C620
# C0C620  problem
# Checking the data on station C0C630
# Checking the data on station C0C650
# Checking the data on station C0C660
# C0C660  problem
# Checking the data on station C0C670
# C0C670  problem
# Checking the data on station C0C680
# C0C680  problem
# Checking the data on station C0D360
# Checking the data on station C0D390
# Checking the data on station C0D430
# C0D430  problem
# Checking the data on station C0D480
# Checking the data on station C0D540
# Checking the data on station C0D550
# Checking the data on station C0D560
# Checking the data on station C0D570
# Checking the data on station C0D580
# C0D580  problem
# Checking the data on station C0D590
# Checking the data on station C0D650
# C0D650  problem
# Checking the data on station C0D660
# C0D660  problem
# Checking the data on station C0E420
# Checking the data on station C0E430
# Checking the data on station C0E520
# C0E520  problem
# Checking the data on station C0E530
# C0E530  problem
# Checking the data on station C0E540
# C0E540  problem
# Checking the data on station C0E550
# C0E550  problem
# Checking the data on station C0E590
# C0E590  problem
# Checking the data on station C0E610
# Checking the data on station C0E730
# Checking the data on station C0E740
# C0E740  problem
# Checking the data on station C0E750
# C0E750  problem
# Checking the data on station C0E780
# C0E780  problem
# Checking the data on station C0E790
# C0E790  problem
# Checking the data on station C0E810
# C0E810  problem
# Checking the data on station C0E820
# C0E820  problem
# Checking the data on station C0E830
# C0E830  problem
# Checking the data on station C0E850
# C0E850  problem
# Checking the data on station C0E860
# C0E860  problem
# Checking the data on station C0E870
# C0E870  problem
# Checking the data on station C0F000
# C0F000  problem
# Checking the data on station C0F0A0
# C0F0A0  problem
# Checking the data on station C0F0B0
# C0F0B0  problem
# Checking the data on station C0F0C0
# C0F0C0  problem
# Checking the data on station C0F850
# C0F850  problem
# Checking the data on station C0F861
# C0F861  problem
# Checking the data on station C0F930
# C0F930  problem
# Checking the data on station C0F970
# C0F970  problem
# Checking the data on station C0F9A0
# C0F9A0  problem
# Checking the data on station C0F9I0
# C0F9I0  problem
# Checking the data on station C0F9K0
# C0F9K0  problem
# Checking the data on station C0F9L0
# C0F9L0  problem
# Checking the data on station C0F9M0
# C0F9M0  problem
# Checking the data on station C0F9N0
# C0F9N0  problem
# Checking the data on station C0F9O0
# C0F9O0  problem
# Checking the data on station C0F9P0
# C0F9P0  problem
# Checking the data on station C0F9Q0
# C0F9Q0  problem
# Checking the data on station C0F9R0
# C0F9R0  problem
# Checking the data on station C0F9S0
# C0F9S0  problem
# Checking the data on station C0F9T0
# C0F9T0  problem
# Checking the data on station C0F9U0
# C0F9U0  problem
# Checking the data on station C0F9V0
# C0F9V0  problem
# Checking the data on station C0F9X0
# C0F9X0  problem
# Checking the data on station C0F9Y0
# C0F9Y0  problem
# Checking the data on station C0F9Z0
# C0F9Z0  problem
# Checking the data on station C0G620
# C0G620  problem
# Checking the data on station C0G640
# C0G640  problem
# Checking the data on station C0G650
# C0G650  problem
# Checking the data on station C0G660
# C0G660  problem
# Checking the data on station C0G720
# C0G720  problem
# Checking the data on station C0G730
# C0G730  problem
# Checking the data on station C0G740
# C0G740  problem
# Checking the data on station C0G750
# C0G750  problem
# Checking the data on station C0G760
# C0G760  problem
# Checking the data on station C0G770
# C0G770  problem
# Checking the data on station C0G780
# C0G780  problem
# Checking the data on station C0G790
# C0G790  problem
# Checking the data on station C0G800
# C0G800  problem
# Checking the data on station C0G810
# C0G810  problem
# Checking the data on station C0G820
# C0G820  problem
# Checking the data on station C0G830
# C0G830  problem
# Checking the data on station C0G840
# C0G840  problem
# Checking the data on station C0G850
# C0G850  problem
# Checking the data on station C0G860
# C0G860  problem
# Checking the data on station C0G870
# C0G870  problem
# Checking the data on station C0G880
# C0G880  problem
# Checking the data on station C0G890
# C0G890  problem
# Checking the data on station C0H890
# C0H890  problem
# Checking the data on station C0H950
# C0H950  problem
# Checking the data on station C0H960
# C0H960  problem
# Checking the data on station C0H990
# C0H990  problem
# Checking the data on station C0H9A0
# C0H9A0  problem
# Checking the data on station C0H9C0
# C0H9C0  problem
# Checking the data on station C0I010
# C0I010  problem
# Checking the data on station C0I080
# C0I080  problem
# Checking the data on station C0I090
# C0I090  problem
# Checking the data on station C0I110
# C0I110  problem
# Checking the data on station C0I360
# C0I360  problem
# Checking the data on station C0I370
# C0I370  problem
# Checking the data on station C0I380
# C0I380  problem
# Checking the data on station C0I390
# C0I390  problem
# Checking the data on station C0I410
# C0I410  problem
# Checking the data on station C0I420
# C0I420  problem
# Checking the data on station C0I460
# C0I460  problem
# Checking the data on station C0I480
# C0I480  problem
# Checking the data on station C0I490
# C0I490  problem
# Checking the data on station C0I520
# C0I520  problem
# Checking the data on station C0K240
# C0K240  problem
# Checking the data on station C0K250
# C0K250  problem
# Checking the data on station C0K280
# C0K280  problem
# Checking the data on station C0K291
# C0K291  problem
# Checking the data on station C0K330
# C0K330  problem
# Checking the data on station C0K390
# C0K390  problem
# Checking the data on station C0K400
# C0K400  problem
# Checking the data on station C0K410
# C0K410  problem
# Checking the data on station C0K420
# C0K420  problem
# Checking the data on station C0K430
# C0K430  problem
# Checking the data on station C0K440
# C0K440  problem
# Checking the data on station C0K450
# C0K450  problem
# Checking the data on station C0K460
# C0K460  problem
# Checking the data on station C0K470
# C0K470  problem
# Checking the data on station C0K480
# C0K480  problem
# Checking the data on station C0K490
# C0K490  problem
# Checking the data on station C0K500
# C0K500  problem
# Checking the data on station C0K510
# C0K510  problem
# Checking the data on station C0K520
# C0K520  problem
# Checking the data on station C0K530
# C0K530  problem
# Checking the data on station C0K550
# C0K550  problem
# Checking the data on station C0K560
# C0K560  problem
# Checking the data on station C0K580
# C0K580  problem
# Checking the data on station C0M410
# C0M410  problem
# Checking the data on station C0M520
# C0M520  problem
# Checking the data on station C0M530
# C0M530  problem
# Checking the data on station C0M640
# C0M640  problem
# Checking the data on station C0M650
# C0M650  problem
# Checking the data on station C0M660
# C0M660  problem
# Checking the data on station C0M670
# C0M670  problem
# Checking the data on station C0M680
# C0M680  problem
# Checking the data on station C0M690
# C0M690  problem
# Checking the data on station C0M700
# C0M700  problem
# Checking the data on station C0M710
# C0M710  problem
# Checking the data on station C0M720
# C0M720  problem
# Checking the data on station C0M730
# C0M730  problem
# Checking the data on station C0M740
# C0M740  problem
# Checking the data on station C0M750
# C0M750  problem
# Checking the data on station C0M760
# C0M760  problem
# Checking the data on station C0M770
# C0M770  problem
# Checking the data on station C0M780
# C0M780  problem
# Checking the data on station C0M790
# C0M790  problem
# Checking the data on station C0M800
# C0M800  problem
# Checking the data on station C0M810
# C0M810  problem
# Checking the data on station C0M820
# C0M820  problem
# Checking the data on station C0M830
# C0M830  problem
# Checking the data on station C0O810
# C0O810  problem
# Checking the data on station C0O830
# C0O830  problem
# Checking the data on station C0O840
# C0O840  problem
# Checking the data on station C0O860
# C0O860  problem
# Checking the data on station C0O900
# C0O900  problem
# Checking the data on station C0O930
# C0O930  problem
# Checking the data on station C0O950
# C0O950  problem
# Checking the data on station C0O960
# C0O960  problem
# Checking the data on station C0O970
# C0O970  problem
# Checking the data on station C0O980
# C0O980  problem
# Checking the data on station C0O990
# C0O990  problem
# Checking the data on station C0R100
# C0R100  problem
# Checking the data on station C0R130
# C0R130  problem
# Checking the data on station C0R140
# C0R140  problem
# Checking the data on station C0R150
# C0R150  problem
# Checking the data on station C0R160
# C0R160  problem
# Checking the data on station C0R170
# C0R170  problem
# Checking the data on station C0R190
# C0R190  problem
# Checking the data on station C0R220
# C0R220  problem
# Checking the data on station C0R240
# C0R240  problem
# Checking the data on station C0R260
# C0R260  problem
# Checking the data on station C0R270
# C0R270  problem
# Checking the data on station C0R280
# C0R280  problem
# Checking the data on station C0R350
# C0R350  problem
# Checking the data on station C0R360
# Checking the data on station C0R370
# Checking the data on station C0R380
# C0R380  problem
# Checking the data on station C0R400
# C0R400  problem
# Checking the data on station C0R420
# C0R420  problem
# Checking the data on station C0R430
# C0R430  problem
# Checking the data on station C0R470
# C0R470  problem
# Checking the data on station C0R480
# C0R480  problem
# Checking the data on station C0R490
# C0R490  problem
# Checking the data on station C0R500
# C0R500  problem
# Checking the data on station C0R510
# C0R510  problem
# Checking the data on station C0R520
# C0R520  problem
# Checking the data on station C0R530
# C0R530  problem
# Checking the data on station C0R540
# C0R540  problem
# Checking the data on station C0R550
# C0R550  problem
# Checking the data on station C0R560
# C0R560  problem
# Checking the data on station C0R570
# C0R570  problem
# Checking the data on station C0R580
# C0R580  problem
# Checking the data on station C0R590
# C0R590  problem
# Checking the data on station C0R600
# C0R600  problem
# Checking the data on station C0R620
# C0R620  problem
# Checking the data on station C0S680
# C0S680  problem
# Checking the data on station C0S690
# Checking the data on station C0S700
# Checking the data on station C0S710
# C0S710  problem
# Checking the data on station C0S730
# Checking the data on station C0S740
# C0S740  problem
# Checking the data on station C0S750
# Checking the data on station C0S760
# C0S760  problem
# Checking the data on station C0S770
# C0S770  problem
# Checking the data on station C0S790
# C0S790  problem
# Checking the data on station C0S810
# C0S810  problem
# Checking the data on station C0S830
# C0S830  problem
# Checking the data on station C0S840
# C0S840  problem
# Checking the data on station C0S890
# C0S890  problem
# Checking the data on station C0T790
# C0T790  problem
# Checking the data on station C0T820
# C0T820  problem
# Checking the data on station C0T870
# C0T870  problem
# Checking the data on station C0T900
# C0T900  problem
# Checking the data on station C0T960
# Checking the data on station C0T9A0
# C0T9A0  problem
# Checking the data on station C0T9B0
# C0T9B0  problem
# Checking the data on station C0T9D0
# C0T9D0  problem
# Checking the data on station C0T9E0
# C0T9E0  problem
# Checking the data on station C0T9F0
# C0T9F0  problem
# Checking the data on station C0T9G0
# C0T9G0  problem
# Checking the data on station C0T9H0
# C0T9H0  problem
# Checking the data on station C0T9I0
# C0T9I0  problem
# Checking the data on station C0T9M0
# C0T9M0  problem
# Checking the data on station C0U520
# C0U520  problem
# Checking the data on station C0U600
# C0U600  problem
# Checking the data on station C0U620
# Checking the data on station C0U650
# C0U650  problem
# Checking the data on station C0U710
# C0U710  problem
# Checking the data on station C0U750
# C0U750  problem
# Checking the data on station C0U760
# Checking the data on station C0U770
# C0U770  problem
# Checking the data on station C0U780
# C0U780  problem
# Checking the data on station C0U860
# C0U860  problem
# Checking the data on station C0U870
# C0U870  problem
# Checking the data on station C0U890
# C0U890  problem
# Checking the data on station C0U900
# C0U900  problem
# Checking the data on station C0U910
# C0U910  problem
# Checking the data on station C0U940
# C0U940  problem
# Checking the data on station C0U950
# C0U950  problem
# Checking the data on station C0U970
# C0U970  problem
# Checking the data on station C0U980
# C0U980  problem
# Checking the data on station C0U990
# C0U990  problem
# Checking the data on station C0V150
# Checking the data on station C0V210
# C0V210  problem
# Checking the data on station C0V250
# C0V250  problem
# Checking the data on station C0V260
# C0V260  problem
# Checking the data on station C0V310
# C0V310  problem
# Checking the data on station C0V350
# C0V350  problem
# Checking the data on station C0V360
# C0V360  problem
# Checking the data on station C0V370
# C0V370  problem
# Checking the data on station C0V400
# C0V400  problem
# Checking the data on station C0V440
# C0V440  problem
# Checking the data on station C0V450
# C0V450  problem
# Checking the data on station C0V490
# C0V490  problem
# Checking the data on station C0V500
# C0V500  problem
# Checking the data on station C0V530
# C0V530  problem
# Checking the data on station C0V610
# C0V610  problem
# Checking the data on station C0V620
# C0V620  problem
# Checking the data on station C0V630
# C0V630  problem
# Checking the data on station C0V640
# C0V640  problem
# Checking the data on station C0V650
# C0V650  problem
# Checking the data on station C0V660
# C0V660  problem
# Checking the data on station C0V670
# C0V670  problem
# Checking the data on station C0V680
# C0V680  problem
# Checking the data on station C0V690
# C0V690  problem
# Checking the data on station C0V700
# C0V700  problem
# Checking the data on station C0V710
# C0V710  problem
# Checking the data on station C0V720
# C0V720  problem
# Checking the data on station C0V730
# C0V730  problem
# Checking the data on station C0V740
# C0V740  problem
# Checking the data on station C0V750
# C0V750  problem
# Checking the data on station C0V760
# C0V760  problem
# Checking the data on station C0V770
# C0V770  problem
# Checking the data on station C0V790
# C0V790  problem
# Checking the data on station C0V800
# C0V800  problem
# Checking the data on station C0V810
# C0V810  problem
# Checking the data on station C0W110
# C0W110  problem
# Checking the data on station C0W120
# C0W120  problem
# Checking the data on station C0W130
# C0W130  problem
# Checking the data on station C0W140
# C0W140  problem
# Checking the data on station C0W150
# C0W150  problem
# Checking the data on station C0W160
# C0W160  problem
# Checking the data on station C0W170
# C0W170  problem
# Checking the data on station C0X050
# C0X050  problem
# Checking the data on station C0X060
# C0X060  problem
# Checking the data on station C0X080
# C0X080  problem
# Checking the data on station C0X100
# C0X100  problem
# Checking the data on station C0X110
# C0X110  problem
# Checking the data on station C0X120
# C0X120  problem
# Checking the data on station C0X130
# C0X130  problem
# Checking the data on station C0X140
# C0X140  problem
# Checking the data on station C0X150
# C0X150  problem
# Checking the data on station C0X160
# C0X160  problem
# Checking the data on station C0X170
# C0X170  problem
# Checking the data on station C0X180
# C0X180  problem
# Checking the data on station C0X190
# C0X190  problem
# Checking the data on station C0X200
# C0X200  problem
# Checking the data on station C0X210
# C0X210  problem
# Checking the data on station C0X220
# C0X220  problem
# Checking the data on station C0X230
# C0X230  problem
# Checking the data on station C0X240
# C0X240  problem
# Checking the data on station C0X250
# C0X250  problem
# Checking the data on station C0X260
# C0X260  problem
# Checking the data on station C0X270
# C0X270  problem
# Checking the data on station C0X280
# C0X280  problem
# Checking the data on station C0X290
# C0X290  problem
# Checking the data on station C0X300
# C0X300  problem
# Checking the data on station C0X310
# C0X310  problem
# Checking the data on station C0Z020
# C0Z020  problem
# Checking the data on station C0Z050
# C0Z050  problem
# Checking the data on station C0Z061
# C0Z061  problem
# Checking the data on station C0Z070
# C0Z070  problem
# Checking the data on station C0Z080
# C0Z080  problem
# Checking the data on station C0Z100
# C0Z100  problem
# Checking the data on station C0Z150
# C0Z150  problem
# Checking the data on station C0Z160
# C0Z160  problem
# Checking the data on station C0Z170
# C0Z170  problem
# Checking the data on station C0Z180
# C0Z180  problem
# Checking the data on station C0Z190
# C0Z190  problem
# Checking the data on station C0Z200
# C0Z200  problem
# Checking the data on station C0Z210
# C0Z210  problem
# Checking the data on station C0Z230
# C0Z230  problem
# Checking the data on station C0Z250
# C0Z250  problem
# Checking the data on station C0Z260
# Checking the data on station C0Z270
# C0Z270  problem
# Checking the data on station C0Z280
# C0Z280  problem
# Checking the data on station C0Z290
# C0Z290  problem
# Checking the data on station C0Z300
# C0Z300  problem
# Checking the data on station C1A630
# C1A630  problem
# Checking the data on station C1A730
# C1A730  problem
# Checking the data on station C1A9N0
# C1A9N0  problem
# Checking the data on station C1AC50
# C1AC50  problem
# Checking the data on station C1C510
# C1C510  problem
# Checking the data on station C1D380
# C1D380  problem
# Checking the data on station C1D400
# C1D400  problem
# Checking the data on station C1D410
# C1D410  problem
# Checking the data on station C1D420
# C1D420  problem
# Checking the data on station C1D630
# C1D630  problem
# Checking the data on station C1D640
# C1D640  problem
# Checking the data on station C1E451
# C1E451  problem
# Checking the data on station C1E461
# C1E461  problem
# Checking the data on station C1E480
# C1E480  problem
# Checking the data on station C1E511
# C1E511  problem
# Checking the data on station C1E601
# C1E601  problem
# Checking the data on station C1E670
# C1E670  problem
# Checking the data on station C1E681
# C1E681  problem
# Checking the data on station C1E691
# C1E691  problem
# Checking the data on station C1E701
# C1E701  problem
# Checking the data on station C1E711
# C1E711  problem
# Checking the data on station C1E721
# C1E721  problem
# Checking the data on station C1E770
# C1E770  problem
# Checking the data on station C1F871
# C1F871  problem
# Checking the data on station C1F891
# C1F891  problem
# Checking the data on station C1F911
# C1F911  problem
# Checking the data on station C1F941
# C1F941  problem
# Checking the data on station C1F9B1
# C1F9B1  problem
# Checking the data on station C1F9C1
# C1F9C1  problem
# Checking the data on station C1F9D1
# C1F9D1  problem
# Checking the data on station C1F9E1
# C1F9E1  problem
# Checking the data on station C1F9F1
# C1F9F1  problem
# Checking the data on station C1F9G1
# C1F9G1  problem
# Checking the data on station C1F9H1
# C1F9H1  problem
# Checking the data on station C1F9J1
# C1F9J1  problem
# Checking the data on station C1F9W0
# C1F9W0  problem
# Checking the data on station C1G690
# Checking the data on station C1H000
# C1H000  problem
# Checking the data on station C1H860
# C1H860  problem
# Checking the data on station C1H900
# C1H900  problem
# Checking the data on station C1H920
# C1H920  problem
# Checking the data on station C1H941
# C1H941  problem
# Checking the data on station C1H971
# C1H971  problem
# Checking the data on station C1H9B1
# C1H9B1  problem
# Checking the data on station C1I020
# C1I020  problem
# Checking the data on station C1I030
# C1I030  problem
# Checking the data on station C1I050
# C1I050  problem
# Checking the data on station C1I070
# C1I070  problem
# Checking the data on station C1I101
# C1I101  problem
# Checking the data on station C1I121
# C1I121  problem
# Checking the data on station C1I131
# C1I131  problem
# Checking the data on station C1I140
# C1I140  problem
# Checking the data on station C1I150
# C1I150  problem
# Checking the data on station C1I201
# C1I201  problem
# Checking the data on station C1I211
# C1I211  problem
# Checking the data on station C1I220
# C1I220  problem
# Checking the data on station C1I230
# C1I230  problem
# Checking the data on station C1I240
# C1I240  problem
# Checking the data on station C1I250
# C1I250  problem
# Checking the data on station C1I260
# C1I260  problem
# Checking the data on station C1I280
# C1I280  problem
# Checking the data on station C1I290
# C1I290  problem
# Checking the data on station C1I310
# C1I310  problem
# Checking the data on station C1I320
# C1I320  problem
# Checking the data on station C1I330
# C1I330  problem
# Checking the data on station C1I340
# C1I340  problem
# Checking the data on station C1I400
# C1I400  problem
# Checking the data on station C1I430
# C1I430  problem
# Checking the data on station C1I440
# C1I440  problem
# Checking the data on station C1I450
# C1I450  problem
# Checking the data on station C1I470
# C1I470  problem
# Checking the data on station C1I500
# C1I500  problem
# Checking the data on station C1I510
# C1I510  problem
# Checking the data on station C1K540
# C1K540  problem
# Checking the data on station C1M390
# C1M390  problem
# Checking the data on station C1M400
# C1M400  problem
# Checking the data on station C1M480
# C1M480  problem
# Checking the data on station C1M570
# C1M570  problem
# Checking the data on station C1M600
# C1M600  problem
# Checking the data on station C1M610
# C1M610  problem
# Checking the data on station C1M620
# C1M620  problem
# Checking the data on station C1N001
# C1N001  problem
# Checking the data on station C1O850
# C1O850  problem
# Checking the data on station C1O870
# C1O870  problem
# Checking the data on station C1O880
# C1O880  problem
# Checking the data on station C1O921
# C1O921  problem
# Checking the data on station C1R110
# C1R110  problem
# Checking the data on station C1R120
# C1R120  problem
# Checking the data on station C1R201
# C1R201  problem
# Checking the data on station C1R250
# C1R250  problem
# Checking the data on station C1R290
# C1R290  problem
# Checking the data on station C1R300
# C1R300  problem
# Checking the data on station C1R320
# C1R320  problem
# Checking the data on station C1R330
# C1R330  problem
# Checking the data on station C1R340
# C1R340  problem
# Checking the data on station C1R440
# C1R440  problem
# Checking the data on station C1R610
# C1R610  problem
# Checking the data on station C1S620
# C1S620  problem
# Checking the data on station C1S630
# C1S630  problem
# Checking the data on station C1S660
# C1S660  problem
# Checking the data on station C1S670
# C1S670  problem
# Checking the data on station C1S800
# C1S800  problem
# Checking the data on station C1S820
# C1S820  problem
# Checking the data on station C1S850
# C1S850  problem
# Checking the data on station C1S860
# C1S860  problem
# Checking the data on station C1S870
# C1S870  problem
# Checking the data on station C1S880
# C1S880  problem
# Checking the data on station C1T800
# C1T800  problem
# Checking the data on station C1T810
# C1T810  problem
# Checking the data on station C1T830
# C1T830  problem
# Checking the data on station C1T920
# C1T920  problem
# Checking the data on station C1T940
# C1T940  problem
# Checking the data on station C1T950
# C1T950  problem
# Checking the data on station C1T970
# C1T970  problem
# Checking the data on station C1T980
# C1T980  problem
# Checking the data on station C1T990
# C1T990  problem
# Checking the data on station C1U501
# C1U501  problem
# Checking the data on station C1U511
# Checking the data on station C1U670
# C1U670  problem
# Checking the data on station C1U690
# C1U690  problem
# Checking the data on station C1U830
# C1U830  problem
# Checking the data on station C1U840
# C1U840  problem
# Checking the data on station C1U850
# C1U850  problem
# Checking the data on station C1U880
# C1U880  problem
# Checking the data on station C1V160
# C1V160  problem
# Checking the data on station C1V170
# C1V170  problem
# Checking the data on station C1V190
# C1V190  problem
# Checking the data on station C1V200
# C1V200  problem
# Checking the data on station C1V220
# C1V220  problem
# Checking the data on station C1V231
# C1V231  problem
# Checking the data on station C1V300
# C1V300  problem
# Checking the data on station C1V340
# C1V340  problem
# Checking the data on station C1V390
# C1V390  problem
# Checking the data on station C1V570
# C1V570  problem
# Checking the data on station C1V580
# C1V580  problem
# Checking the data on station C1V590
# C1V590  problem
# Checking the data on station C1V600
# C1V600  problem
# Checking the data on station C1V780
# C1V780  problem
# Checking the data on station C1X040
# C1X040  problem
# Checking the data on station C1Z030
# C1Z030  problem
# Checking the data on station C1Z040
# C1Z040  problem
# Checking the data on station C1Z110
# C1Z110  problem
# Checking the data on station C1Z120
# C1Z120  problem
# Checking the data on station C1Z130
# C1Z130  problem
# Checking the data on station C1Z240
# C1Z240  problem
